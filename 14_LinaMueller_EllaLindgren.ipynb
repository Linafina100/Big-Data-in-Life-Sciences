# %% [markdown]
# # Assignment 3

# %% [markdown]
# # 📘 Deep Learning Assignment
#
# 👥 **Group members:** Lina Müller & Ella Lindgren
# 🗓️ **Deadline:** See Studium
#
# 📤 Submit:
# - Both `.ipynb` and `.pdf` versions
# - Restart and run all cells before exporting
# - Follow the filename format:
# 'GroupNumber_Student1_Student2.ipynb'
#   `42_EbbaBergman_AkshaiParakkalSreenivasan.ipynb`

# %% [markdown]
# ## 🧭 Before You Start
# > ⚠️ **Important:**
# > Before running this notebook, you **must shut down all other notebooks and kernels**.
# > Running multiple notebooks at once can cause memory issues and slowdowns — especially with image data.
# > Use the stop icon (■) in the Jupyter sidebar to shut down any active sessions.
#
# >  **If this notebook doesn't run at any point:**
#   >1. Try rerunning the cell
#   >2. If stuck, interrupt the cell
#   >3. Restart the kernel and run all necessary cells again

# %% [markdown]
# ## Data
# There's a whole thesis written based on this dataset, available here: http://uu.diva-portal.org/smash/get/diva2:1650957/FULLTEXT01.pdf . The thesis then resulted in a paper: https://openaccess.thecvf.com/content_ICCV_2017_workshops/w1/html/Wieslander_Deep_Convolutional_Neural_ICCV_2017_paper.html
#
#
# A quote from Weislander et al. regarding the dataset:
#
# "The cell samples were collected at Södersjukhuset in Stockholm. The patients have mixed genders, are non smoking, some are human papillomavirus (HPV) positive and some are not, and they have an age span of 47-77 years. From each patient samples were collected with a brush that is scraped at areas of interest in the oral cavity. Each scrape is then smeared out on a glass, which is then stained to highlight important cellular structures"
#
# ## Notes
# This assignment is inspired by Phil Harrisons lab for Pharmaceutical Bioinformatics and Sequence Analysis  from 2021
#
# **You are not allowed to use the exact same network and configurations as in these texts, or copy directly from the labs, but you are allowed to use the same base network if you are using transfer learning. The network you use here must be significantly different from any other network you've used in the labs or read about in the paper above**
#
# You may discuss theory with other groups, but not code nor share code. You may not use ChatGPT4 or similar programs to generate a solution, code, nor answers to the questions
#
#  <span style="color:red"> Solutions deemed to similar will be run through a program designed to detect coding plagirism and if flagged you will be reported for plagirism. </span>
#
#  One hand in per group.

# %% [markdown]
#  ## Hand in
#  Hand in one pdf file and one .ipynb file. The notebook must be runnable with the data, any teacher might run the notebook to check that it actually works. Notebooks that do not run will need to be redone without further feedback. You may redo this hand in twice before failing the assignment all togehter.
#
# ## Report structure
#  You must follow the reportstructure to pass the assignment. Notebooks that do not follow the reportstructure will be sent back to be redone without further feedback.
#  The full reporstructure is specified at the end of this notebook

# %% [markdown]
# ## Goal
# Design a neural network that achieves at least 82% balanced accuracy while demonstrating an understanding of the decisions made throughout the process as well as the strengths and limitations of the final model.
#
# ---
#
# ## Tasks
#
# 1. Build a neural network that achieves less than 65% balanced accuracy on the validation set
#
# 2. Build a neural network that achieves at least 82% balanced accuracy on the validation set, demonstrating the
#
#     * Start with an initial model, improve it step by step until you reach the target accuracy
#         *
#     * Show atleast 2 distinct stages of your model
#         * For each stage, clearly describe:
#             - what you changed
#             - why you made that choice
#         * As you build on the previous model you need demonstrate the new improvements based on the lates model. I.e. if the inital model is A, after your first improvement your model is B, then the the next improvement will be made on B (or later), not A.
#         * If you show different stages further apart you need to show the previous stage as well. E.g A->B, D->E
#
#         * If your  model reached the target accuracy with fewer than 2 changes:
#             Continue modifying the model until you have at least two changes in total
#             Reflect on whether later changes improved or worsened performance
#
# 3. Report your final balanced accuracy at the top of the notebook (in the question section)
#
# 4. Answer all questions in the question section

# %% [markdown]
# ## Question section
#
# ### Accuracies
#
# **Total balanced accuracy:**
# *Validation: 0.8231, Test: 0.8220*
#
# **Accuracy per class:**
# Validation Set
# Healthy Class Accuracy: 0.79
# Tumor Class Accuracy: 0.85
#
# Test Set
# Healthy Class Accuracy: 0.83
# Tumor Class Accuracy: 0.82
#
# **Any other measurements you would like to include:**
# *(For example: precision, recall, F1-score, confusion matrix, etc. Briefly explain why you chose these)*

# %% [markdown]
# ### Questions
#
# **Q1:** If a clinician requires 80% accuracy in their model, would you recommend using the model you have developed? Why or why not?
# (Think about reliability, generalisation, and whether accuracy alone is sufficient.)
#
# **A1:**
# No, we would not recommend using the model based solely on 80% accuracy requirement. Accuracy is not sufficient in medical diagnostics. If the dataset is imbalanced, eg 90% healthy and 10% ill, a model that guesses healthy every time will have 90% accuracy while missing 100% of the tumors. Therefore, we must use recall to ensure that we are not missing ill patients.
#
# **Q2:** Your model went through several changes. Which specific change had the largest impact on performance, and why do you think that was the case?
#
# **A2:**
# We think that tuning the learning rate had a great impact on our model. The learning rate ensures a more controlled and careful learning that improved our accuracy. We could see that the fluctuations were smoothed out for lower accuracy values. This stabilitezed the training. In addition, adjusting the class weights was important because it made the model focus more on correctly identifying tumor samples. Since the dataset was imbalanced, increasing the weight of the tumor class helped improve the recall for tumor samples and contributed to a better balanced accuracy.
#
# **Q3:** In this dataset, patients were mixed together before splitting the data into training and validation sets. What is the main drawback of this approach?
#
# **A3:**
# There is a risk of data leakage, since cells from the same patient have smilier biological traits. If samples from the same patient appear in both the training and validation sets, the model may learn patient specific patterns rather than general biological patterns. This makes the validation performance appear higher because the model is partly being tested on data it has effectively already seen. This leads to worse generalization.
#
# **Q4:** What is a potential benefit of mixing patients before splitting the data?
#
# **A4:**
# So there is no bias in the datasets (training and validation sets are identically distributed). We need balanced datasets to make the model generalizable.
#
# **Q5:** How might the results change if you instead split the data by patient (i.e. ensuring that cells from the same patient are only in either training or validation, not both)? Explain your reasoning.
#
# **A5:**
# If the data were split by patient, the model performance would likely decrease because it would need to generalize to completely unseen patients instead of learning patient specific patterns. Even though this score probably will be lower, it is a  more true reflection of the model performance.
#
# **Q6:** Besides accuracy, what other evaluation metrics could be important for this task, and why?
#
# **A6:**
# Because it is more dangerous to miss an infected patient than to diagnose a healthy patient as infected, better metrics would be recall. Recall asks: Out of all people that have HPV how many did the model correctly identify? Precision can also be good to evaluate. Precision asks: out all patients that the model predicted as HPV positive how many actually have it.
#
# **Q7:** If your model performs well on the validation set but poorly in a real clinical setting, what could be the reason for this mismatch?
#
# **A7:**
# Overfit due to data leakage (the model memorised patient-specific traits because patients were mixed during the split). Other reasons: the validation data set is not representative of the patient group, bad tuning, too small data set, not balanced data set etc.

# %% [markdown]
# # Set up

# %%
import cv2
import os
import random

import numpy as np
import pandas as pd
import IPython
import matplotlib.pyplot as plt


from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight

from datetime import datetime

from importlib.machinery import SourceFileLoader

from IPython.display import display, HTML

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, preprocessing
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2026-05-23 07:04:23.899362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-23 07:04:23.932260: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-23 07:04:23.932320: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-23 07:04:23.954003: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Configure GPUs
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      print("Done setting memory_growth")
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except Exception as e:
    # Memory growth must be set before GPUs have been initialized
    print("If you get this , probably done already")
    # Catch the exception and display a custom HTML message with red text
    message = """There was some problems setting up the GPU,
                 it is probably best to restart kernel and clear
                 all outputs before starting over
              """
    display(HTML(f"<div style='color: red;'><strong>Warning:</strong>{message}</div>"))
    print(e)
# Out:
# Num GPUs Available:  1
# Done setting memory_growth
# 1 Physical GPUs, 1 Logical GPUs
# 2026-05-23 07:05:52.299697: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10527 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0f:00.0, compute capability: 6.1

# %% [markdown]
# # Paths

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# /home/jovyan/big-data_deeplearning/Assignments

# %%
base_path = '/home/jovyan/big-data_deeplearning/'  # Students will need to update

assignments_directory = os.path.join(base_path, 'Assignments')

hpv_images_directory = os.path.join(assignments_directory, 'Data', 'HPV_slides')  # Students will need to update

# %%
from load_helpers import load_helpers
helpers, cnn_helper, plot_helper = load_helpers(assignments_directory)

# %% [markdown]
# ### Setup HPV data

# %% [markdown]
# Extract the HPV data  using the HPV_v2_data_prep.ipynb notebook
# You will need to update the directories in that notebook, and the directories below to match

# %%
# directories for our training, validation and test splits
train_directory = os.path.join(hpv_images_directory, 'train')
validation_directory = os.path.join(hpv_images_directory, 'validation')
test_directory = os.path.join(hpv_images_directory, 'test')

# directory with our training healthy cell images
train_healthy_directory = os.path.join(train_directory, 'healthy')

# directory with our training tumor cell images
train_tumor_directory = os.path.join(train_directory, 'tumor')

# directory with our validation healthy cell images
validation_healthy_directory = os.path.join(validation_directory, 'healthy')

# directory with our validation tumor cell images
validation_tumor_directory = os.path.join(validation_directory, 'tumor')

# directory with our test healthy cell images
test_healthy_directory = os.path.join(test_directory, 'healthy')

# directory with our test tumor cell images
test_tumor_directory = os.path.join(test_directory, 'tumor')

# %%
#### Data check

print('Number of  healthy images for training:', len(os.listdir(train_healthy_directory)))
print('Number of  tumor images for training:', len(os.listdir(train_tumor_directory)))
print('')
print('Number of  healthy images for validation:', len(os.listdir(validation_healthy_directory)))
print('Number of  tumor imagess for validation:', len(os.listdir(validation_tumor_directory)))
print('')
print('Number of  healthy images for testing:', len(os.listdir(test_healthy_directory)))
print('Number of  tumor images for testing:', len(os.listdir(test_tumor_directory)))
# Out:
# Number of  healthy images for training: 1247
# Number of  tumor images for training: 768
#
# Number of  healthy images for validation: 317
# Number of  tumor imagess for validation: 213
#
# Number of  healthy images for testing: 437
# Number of  tumor images for testing: 247

# %% [markdown]
# > ⚠️ **Important:**
# > **shut down the HPV_v3_data_prep.ipynb notebook**.
# > Running multiple notebooks at once can cause memory issues and slowdowns — especially with image data.
# > Use the stop icon (■) in the Jupyter sidebar to shut down any active sessions.

# %% [markdown]
# ## Plot sample images

# %%
plot_helper.show_random_images_hpv_specific(train_healthy_directory)

# %% [markdown]
# ## Other setup

# %%
x_len = 96
y_len = 96
batch_size = 32
n_epochs = 10
class_labels=['healthy', 'tumor']

## Note: You might want to change the datagenerators, if so include that in yours steps below,
# ** do not add the changes here unless they're needed for your first model**
# Changes done to make another architecture run will not count as one of the 3 changes you need to make.
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=10,
    zoom_range=0.1
)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

print('TRAINING DATA:')
train_generator = train_datagen.flow_from_directory(
    train_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='binary'
)

print('')
print('VALIDATION DATA:')
validation_generator = validation_datagen.flow_from_directory(
    validation_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='binary',
    shuffle=False
)

print('')
print('TEST DATA:')
test_generator = test_datagen.flow_from_directory(
    test_directory,
    target_size=(x_len, y_len),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='binary',
    shuffle=False
)

class_weights_array = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weights = dict(zip(np.unique(train_generator.classes), class_weights_array))
# Out:
# TRAINING DATA:
# Found 2015 images belonging to 2 classes.
#
# VALIDATION DATA:
# Found 530 images belonging to 2 classes.
#
# TEST DATA:
# Found 684 images belonging to 2 classes.

# %% [markdown]
# # Functions

# %%
  
def get_image_data_flat_from_file(data_directory, image_paths):
    file_names = image_paths.values.flatten() # Assumes image_paths come in df[image_path_column_name] structure due to lab
    image_data = np.array([np.array(cv2.imread(data_directory + file_name)) for file_name in file_names])
    flattened_image_data = image_data.reshape(image_data.shape[0], -1)
    return flattened_image_data

# %% [markdown]
# # STUDENT CODE BEGINS

# %% [markdown]
# You can add new markdown and code cells in the menues at the top of the notebook interface.

# %% [markdown]
# # 🧾 Report Structure
#
# For each task, use the following structure:
#
# ## General structure
# - Use **Markdown cells** to structure and explain your work
# - Use **Code cells** for models, training, and evaluation
# - The **explanation must come before the code** for each model or improvement
# - Avoid vague statements such as “it improved performance” — **quantify your results where possible**
#
# ---
#
# ## Per task
#
# - Markdown cell: **Task number** as a header
# - Markdown cell: **Description of the task**
#     - Describe:
#         - choices made
#         - motivations (for *all* models, not only changes)
#         - reflections on results and any changes made (where appropriate)
#     - See example below for how to structure this
#
# - Markdown cell: **Start of code section**
# - Code cells:
#     - Model definition
#     - Training
#     - Evaluation
#
# - Use **Markdown cells** to clearly separate different parts of your code
#
# ---
#
# ## For each model, include:
#
# - Motivation for the model design (even if it is not a change from a previous model)
# - Model code
# - Comment indicating what part of the model has changed (where appropriate)
# - Validation curves
# - Confusion matrix
# - Accuracy and balanced accuracy
#
#
# ---
#
# ### 🔄 Example: Switching to ELU Activation
# *(Note: You cannot use ELU activation as one of your improvements, nor copy any of this language directly. Plagiarism will be reported.)*
#
# #### Structure of answer
#
# **1. Observation:**
# Training and validation accuracy increased only slowly for cnn_model_1, and there were signs of flat gradients in the first few epochs.
#
# **2. Interpretation:**
# This suggested that the ReLU activations may have led to dead neurons early in training, especially since some of the inputs may have low or negative-valued distributions after normalisation.
#
# **3. Change Made:**
# We replaced ReLU with ELU (Exponential Linear Unit) in all convolutional and dense layers.
#
# **4. Justification:**
# Unlike ReLU, which outputs zero for all negative inputs, ELU allows small negative values. This helps avoid “dead” neurons and encourages more consistent gradient flow during early training. ELU can improve convergence in deeper networks or datasets where feature values include negative ranges.
#
# **5. Short Discussion of Results:**
# With ELU, the training converged slightly faster, and validation accuracy increased more smoothly. This supports the idea that ELU helped mitigate early learning stagnation. It was a worthwhile change for this setting.
#
# ---
#
# #### Answer as text
#
# For cnn_model_1 we observed that both training and validation accuracy improved only gradually during the early epochs. This suggested that some neurons might have become inactive due to the use of ReLU activation. Since ReLU outputs zero for all negative inputs, it can sometimes cause "dead neurons," especially when inputs are close to zero after normalisation.
#
# To address this, we replaced ReLU with ELU (Exponential Linear Unit) in all convolutional and dense layers. ELU allows small negative outputs, which helps preserve gradient flow and prevents early layers from becoming inactive. This change led to slightly faster convergence and a smoother increase in validation accuracy.
#
# The improvement supports the idea that ELU helped reduce early learning stagnation, and it was a suitable choice for this setting.

# %% [markdown]
# ### Task 1
#
# **Description of the task:**
# To establish a baseline model that purposefully achieves less than 65% balanced accuracy, the network must be heavily constrained so it underfits the data.
#
# **Motivation and Model Design:**
# We designed an extremely shallow Convolutional Neural Network (CNN). By restricting the architecture to a single convolutional layer with only 8 filters and a relatively large pooling size, the model lacks the capacity to learn the complex, fine-grained cellular features required to distinguish between healthy and tumor cells accurately.

# %%
# Baseline model

# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Pass inputs through a restricted convolutional and pooling layer
x = layers.Conv2D(filters=8, kernel_size=(3, 3), activation='sigmoid')(cnn_inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_1 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Baseline")

# 2. Compile the model
cnn_model_1.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_1.summary()
# Out:
# Model: "Baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 94, 94, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 47, 47, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 17672)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        17,673 │
# ...

# %%
# 3. Train the model
print("\n--- Starting Training for Baseline Model ---")
history_1 = cnn_model_1.fit(
    train_generator,
    epochs=5,
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training for Baseline Model ---
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779519978.107007  216015 service.cc:145] XLA service 0x7a8d60027c10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779519978.107093  216015 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_1,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.4472
# Balanced accuracy: 0.5302
# Macro F1 score: 0.3846
# Weighted F1 score: 0.3461
#
#               precision    recall  f1-score   support
#
#      healthy       0.77      0.11      0.19       317
#        tumor       0.42      0.95      0.58       213
#
#     accuracy                           0.45       530
#    macro avg       0.60      0.53      0.38       530
# weighted avg       0.63      0.45      0.35       530

# %%
plot_helper.plot_history(history_1, "Baseline Model")

# %% [markdown]
# ## TASK 1: First Change of Baseline Model, Improved Model 2
#
# **1. Observation:**
# The training accuracy showed only a slight increase, while the validation accuracy remained highly unstable.
#
# **2. Interpretation:**
# This behavior indicates that the model is underfitting the data and requires more time processing the images to properly learn the underlying patterns.
#
# **3. Change Made:**
# To address this, the total number of training epochs was increased.
#
# **4. Justification:**
# Increasing the number of epochs gives the network more time to learn patterns from the training data.
#
# **5. Short Discussion of Results:**
# Although the overall accuracy improved slightly with the extra training time, the model remains underfitted and currently suffers from a lower recall score, meaning it is still missing too many positive tumor cases.

# %%
# Improved model 2

# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Pass inputs through convolutional and pooling layer
x = layers.Conv2D(filters=8, kernel_size=(3, 3), activation='sigmoid')(cnn_inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_2 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Model2")

# Compile the model
cnn_model_2.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_2.summary()
# Out:
# Model: "Model2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 94, 94, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 47, 47, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 17672)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │        17,673 │
# ...

# %%
# Train the model
print("\n--- Starting Training for Model2---")
history_2 = cnn_model_2.fit(
    train_generator,
    epochs=15, # changed: Number of epochs from 5 to 15
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training for Model2---
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.5224 - loss: 1.3499 - val_accuracy: 0.5981 - val_loss: 0.7883
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.5080 - loss: 0.8322 - val_accuracy: 0.4019 - val_loss: 0.9196
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.4813 - loss: 0.7707 - val_accuracy: 0.6774 - val_loss: 0.6616
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.5713 - loss: 0.7252 - val_accuracy: 0.4019 - val_loss: 0.7983
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.4976 - loss: 0.7554 - val_accuracy: 0.4019 - val_loss: 0.7977
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.5321 - loss: 0.7568 - val_accuracy: 0.6094 - val_loss: 0.6251
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.5707 - loss: 0.6813 - val_accuracy: 0.7094 - val_loss: 0.6067
# Epoch 8/15
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_2,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
plot_helper.plot_history(history_2, "Model 2")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.7057
# Balanced accuracy: 0.7116
# Macro F1 score: 0.7021
# Weighted F1 score: 0.7085
#
#               precision    recall  f1-score   support
#
#      healthy       0.80      0.68      0.73       317
#        tumor       0.61      0.74      0.67       213
#
#     accuracy                           0.71       530
#    macro avg       0.70      0.71      0.70       530
# weighted avg       0.72      0.71      0.71       530

# %% [markdown]
# ### TASK 2: Second Change of Baseline Model, Improved Model 3¶
# 1. Observation: Validation accuracy is unstable. Model still underfits
#
# 2. Interpretation: The network is struggling to learn the complex, non-linear patterns required to accurately distinguish between healthy tissue and tumor structures.
#
#
# 3. Change Made: Introduced the ReLU (Rectified Linear Unit) activation function to the hidden layers.
#
# 4. Justification:  Changed activation function from sigmoid to relu because sigmoid squashes the values into a small range, which makes the gradients very tiny during backpropagation. When gradients become too small, the network updates its weights very slowly or not at all. Relu does not compress positive values, so the gradients stay much larger and more stable during training.
#
# 5. Short Discussion of Results: The model's ability to learn the training data improved, but the continued instability in validation accuracy suggests the architecture still lacks the depth needed to generalize well.

# %%
# Model 3

# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Pass inputs through a convolutional and pooling layer
x = layers.Conv2D(filters=8, kernel_size=(3, 3), activation='relu')(cnn_inputs) # changed activation function
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_3 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Model3")

# Compile the model
cnn_model_3.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_3.summary()
# Out:
# Model: "Model3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 94, 94, 8)      │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 47, 47, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 17672)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │        17,673 │
# ...

# %%
# Train the model
print("\n--- Starting Training Model3---")
history_3 = cnn_model_3.fit(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training Model3---
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.5201 - loss: 0.6932 - val_accuracy: 0.5547 - val_loss: 0.6840
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.5811 - loss: 0.6717 - val_accuracy: 0.5226 - val_loss: 0.6833
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6341 - loss: 0.6333 - val_accuracy: 0.6396 - val_loss: 0.6391
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.6882 - loss: 0.6014 - val_accuracy: 0.5170 - val_loss: 0.7294
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6614 - loss: 0.6015 - val_accuracy: 0.6434 - val_loss: 0.6340
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7000 - loss: 0.5791 - val_accuracy: 0.7377 - val_loss: 0.5590
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.6937 - loss: 0.5806 - val_accuracy: 0.7264 - val_loss: 0.5449
# Epoch 8/15
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_3,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
plot_helper.plot_history(history_3, "Model 3")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.7075
# Balanced accuracy: 0.7162
# Macro F1 score: 0.7048
# Weighted F1 score: 0.7104
#
#               precision    recall  f1-score   support
#
#      healthy       0.81      0.67      0.73       317
#        tumor       0.61      0.76      0.68       213
#
#     accuracy                           0.71       530
#    macro avg       0.71      0.72      0.70       530
# weighted avg       0.73      0.71      0.71       530

# %% [markdown]
# ### TASK 3: Improved Model 4
# 1. Observation: Validation accuracy was unstable, indicating that the model was not fully generalizable.
#
# 2. Interpretation: The model likely had too few filters to capture the complex features needed to distinguish healthy cells from tumor cells effectively.
#
# 3. Change Made: Increased the number of filters from 8 to 32.
#
# 4. Justification: Increasing the filters from 8 to 32 gives the network the larger capacity to detect more complex cellular textures required to differentiate healthy cells from tumors.
#
# 5. Short Discussion of Results: The model showed small improvement in accuracy, and the validation accuracy fluctuated less compared to the previous model, indicating slightly better generalization.

# %%
# Model 4
keras.backend.clear_session()

# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Pass inputs through a convolutional and pooling layer
x = layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(cnn_inputs) # changed filter size
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_4 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Model4")

model_4_optimizer = keras.optimizers.Adam()

# Compile the model
cnn_model_4.compile(
    optimizer=model_4_optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_4.summary()
# Out:
# Model: "Model4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 94, 94, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 47, 47, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 70688)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        70,689 │
# ...

# %%
# Train the model
print("\n--- Starting Training for Model4---")
history_4 = cnn_model_4.fit(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training for Model4---
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.4871 - loss: 0.9003 - val_accuracy: 0.7283 - val_loss: 0.6675
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6487 - loss: 0.6608 - val_accuracy: 0.7302 - val_loss: 0.6274
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.6857 - loss: 0.6273 - val_accuracy: 0.6151 - val_loss: 0.6589
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.6758 - loss: 0.6066 - val_accuracy: 0.6736 - val_loss: 0.5953
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7135 - loss: 0.5897 - val_accuracy: 0.7170 - val_loss: 0.5675
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.7091 - loss: 0.5675 - val_accuracy: 0.7283 - val_loss: 0.5619
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7070 - loss: 0.5873 - val_accuracy: 0.7113 - val_loss: 0.5594
# Epoch 8/15
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_4,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
plot_helper.plot_history(history_4, "Model 4")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.7057
# Balanced accuracy: 0.7147
# Macro F1 score: 0.7030
# Weighted F1 score: 0.7085
#
#               precision    recall  f1-score   support
#
#      healthy       0.81      0.67      0.73       317
#        tumor       0.61      0.76      0.68       213
#
#     accuracy                           0.71       530
#    macro avg       0.71      0.71      0.70       530
# weighted avg       0.73      0.71      0.71       530

# %% [markdown]
# ### TASK 4: Improved Model 4
# 1. Observation: The model showed a small improvement in accuracy, and the validation accuracy fluctuated less compared to the previous model, indicating slightly better generalization. However, both the accuracy and balanced accuracy were still relatively low.
#
# 2. Interpretation: The model was likely underfitting the data and did not have enough complexity to learn all relevant image features.
#
# 3. Change Made: Added three additional convolutional layers and doubled the number of filters in each subsequent layer.
#
# 4. Justification: Adding more convolutional layers allows the network to learn more hierarchical and complex image features, which can improve its ability to distinguish between healthy and tumor cells. Doubling the number of filters in deeper layers too increases the model’s capacity to detect increasingly complex patterns and textures. Hoping that this will result in higher accuracy.
#
# 5. Short Discussion of Results: The model showed improved accuracy compared to the previous version. However, the precision was still somewhat lower, suggesting that the model continued to produce some false positive predictions.

# %%
# Model 5
keras.backend.clear_session()

# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Changed: Pass inputs through 4 convolutional and pooling layers

# Layer 1
x = layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(cnn_inputs) # changed filter size
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x) # changed filter size
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(x) # changed filter size
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 4
x = layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(x) # changed filter size
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_5 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Model5")

# Compile the model
cnn_model_5.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_5.summary()
# Out:
# Model: "Model5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 94, 94, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 47, 47, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 45, 45, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 22, 22, 64)     │             0 │
# ...

# %%
# Train the model
print("\n--- Starting Training for Model5---")
history_5 = cnn_model_5.fit(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training for Model5---
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 140ms/step - accuracy: 0.5666 - loss: 0.6847 - val_accuracy: 0.4019 - val_loss: 0.8118
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.5873 - loss: 0.6685 - val_accuracy: 0.6585 - val_loss: 0.6061
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.6406 - loss: 0.6280 - val_accuracy: 0.6245 - val_loss: 0.6223
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.6572 - loss: 0.5990 - val_accuracy: 0.7057 - val_loss: 0.5617
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.6619 - loss: 0.6152 - val_accuracy: 0.6943 - val_loss: 0.5798
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7000 - loss: 0.5943 - val_accuracy: 0.7057 - val_loss: 0.5531
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7113 - loss: 0.5657 - val_accuracy: 0.6623 - val_loss: 0.5918
# Epoch 8/15
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_5,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
plot_helper.plot_history(history_5, "Model 5")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.7000
# Balanced accuracy: 0.7199
# Macro F1 score: 0.6995
# Weighted F1 score: 0.7019
#
#               precision    recall  f1-score   support
#
#      healthy       0.84      0.62      0.71       317
#        tumor       0.59      0.82      0.69       213
#
#     accuracy                           0.70       530
#    macro avg       0.71      0.72      0.70       530
# weighted avg       0.74      0.70      0.70       530

# %% [markdown]
# ### TASK 5: Improved Model 6
# 1. Observation: The model still showed too low accuracy, validation accuracy still not stable.
#
# 2. Interpretation: The network's learning process is unstable. As the early layers update their weights during training, the mathematical inputs to the deeper layers constantly shift, making it difficult for the model to confidently learn precise features.
#
# 3. Change Made: Batchnormalization
#
# 4. Justification: Batch Normalization is a stabilizer. By re-centering and scaling the data after each convolutional block, it prevents extreme values from throwing the model's learning off course. allowing for faster and more stable convergence.
#
# 5. Short Discussion of Results: Still imbalance and lower precision but higher overall accuracy, still under 0.82 balnced accuracy.

# %%
# Model 6
keras.backend.clear_session()
# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Pass inputs through a convolutional and pooling layer

# Layer 1
x = layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(cnn_inputs) 
x = layers.BatchNormalization()(x) # Changed: Normalization of the activations to improve stability and convergence
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x) 
x = layers.BatchNormalization()(x) # Changed: Normalization of the activations to improve stability and convergence
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(x) 
x = layers.BatchNormalization()(x) # Changed: Normalization of the activations to improve stability and convergence
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 4
x = layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(x) 
x = layers.BatchNormalization()(x) # Changed: Normalization of the activations to improve stability and convergence
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_6 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Model6")

# Compile the model
cnn_model_6.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_6.summary()
# Out:
# Model: "Model6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 94, 94, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 94, 94, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 47, 47, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# 3. Train the model
print("\n--- Starting Training for Model6---")
history_6 = cnn_model_6.fit(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training for Model6---
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 16s 149ms/step - accuracy: 0.6827 - loss: 0.8717 - val_accuracy: 0.4019 - val_loss: 1.2810
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7742 - loss: 0.5398 - val_accuracy: 0.4019 - val_loss: 2.3829
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7329 - loss: 0.6034 - val_accuracy: 0.4019 - val_loss: 2.7802
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7481 - loss: 0.5632 - val_accuracy: 0.4019 - val_loss: 1.8491
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7689 - loss: 0.4969 - val_accuracy: 0.4019 - val_loss: 2.2971
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.7478 - loss: 0.5403 - val_accuracy: 0.4019 - val_loss: 2.4564
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7511 - loss: 0.5257 - val_accuracy: 0.4019 - val_loss: 2.0280
# Epoch 8/15
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_6,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
plot_helper.plot_history(history_6, "Model 6")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.6528
# Balanced accuracy: 0.5742
# Macro F1 score: 0.5287
# Weighted F1 score: 0.5762
#
#               precision    recall  f1-score   support
#
#      healthy       0.64      0.97      0.77       317
#        tumor       0.82      0.17      0.29       213
#
#     accuracy                           0.65       530
#    macro avg       0.73      0.57      0.53       530
# weighted avg       0.71      0.65      0.58       530

# %% [markdown]
# ### TASK 6: Improved Model 7
# 1. Observation: Validation accuracy still unstable and accuracy too low.
#
# 2. Interpretation: The model is underfitting and not generalizing well to unseen data
#
# 3. Change Made: Added a data augmentation block including horizontal and vertical flips, as well as a rotation of 0.2.
#
# 4. Justification: Data augmentation increases the diversity of the training data by creating modified versions of existing images. This helps the model learn more robust and invariant features, reducing underfitting and improving generalization to unseen data.
#
# 5. Short Discussion of Results: Validation accuracy is still unstable, but overall accuracy improved compared to the previous model, suggesting that the model benefits from the increased variability in the training data.

# %%
# Model 7
keras.backend.clear_session()

# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Changed: Data Augmentation Block, flip and rotation
x = layers.RandomFlip("horizontal_and_vertical")(cnn_inputs)
x = layers.RandomRotation(0.2)(x)

# Pass inputs through convolutional and pooling layers

# Layer 1
x = layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(cnn_inputs) 
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(x) 
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 4
x = layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_7 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Model7")

# Compile the model
cnn_model_7.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_7.summary()
# Out:
# Model: "Model7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 94, 94, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 94, 94, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 47, 47, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Train the model
print("\n--- Starting Training for Model7---")
history_7 = cnn_model_7.fit(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training for Model7---
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.6683 - loss: 1.0720 - val_accuracy: 0.4019 - val_loss: 1.2966
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.7425 - loss: 0.5409 - val_accuracy: 0.4019 - val_loss: 1.8492
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7523 - loss: 0.5401 - val_accuracy: 0.4019 - val_loss: 2.2239
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7414 - loss: 0.5358 - val_accuracy: 0.4019 - val_loss: 2.1090
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7736 - loss: 0.5017 - val_accuracy: 0.4000 - val_loss: 1.0159
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7579 - loss: 0.5130 - val_accuracy: 0.4019 - val_loss: 2.2425
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7514 - loss: 0.5386 - val_accuracy: 0.4019 - val_loss: 2.0954
# Epoch 8/15
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_7,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
plot_helper.plot_history(history_7, "Model 7")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.7830
# Balanced accuracy: 0.7793
# Macro F1 score: 0.7764
# Weighted F1 score: 0.7840
#
#               precision    recall  f1-score   support
#
#      healthy       0.83      0.80      0.81       317
#        tumor       0.72      0.76      0.74       213
#
#     accuracy                           0.78       530
#    macro avg       0.77      0.78      0.78       530
# weighted avg       0.79      0.78      0.78       530

# %% [markdown]
# ### TASK 7: Improved Model 8
# Observation: While the training metrics steadily improved, the validation loss and accuracy graphs show spikes, and the model is still over-predicting tumors (high recall, low precision).
#
# Interpretation: The model is struggling to find a stable mathematical path through the complex, constantly shifting augmented data, causing its performance on the validation set to flactuate a lot.
#
# Change Made: Introduced a slower custom learning rate (0.0001).
#
# Justification: Slowing down the optimizer prevents it from taking overly aggressive steps, which is necessary when forcing the network to learn from randomly flipped and rotated images.
#
# Short Discussion of Results: This successfully stabilized the validation metrics and reduced the model's tendency to over-predict tumors, bringing the overall balanced accuracy up.

# %%
# Model 8
keras.backend.clear_session()

# Define the input layer matching the 96x96 grayscale images
cnn_inputs = keras.Input(shape=(x_len, y_len, 1))

# Data Augmentation Block
x = layers.RandomFlip("horizontal_and_vertical")(cnn_inputs)
x = layers.RandomRotation(0.2)(x)

# Pass inputs through convolutional and pooling layers

# Layer 1
x = layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(cnn_inputs) 
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 2
x = layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x) 
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 3
x = layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Layer 4
x = layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(x) 
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the 2D arrays for the final dense layer
x = layers.Flatten()(x)

# Binary output node (1 unit, sigmoid activation for healthy vs tumor)
cnn_outputs = layers.Dense(units=1, activation='sigmoid')(x)

# Construct the final model
cnn_model_8 = keras.Model(inputs=cnn_inputs, outputs=cnn_outputs, name="Model8")

# Changed: Lowered learning rate.
adam2 = keras.optimizers.Adam(learning_rate=0.0001)

# Compile the model
cnn_model_8.compile(
    optimizer=adam2,
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display the architecture
cnn_model_8.summary()
# Out:
# Model: "Model8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 96, 96, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 94, 94, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 94, 94, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 47, 47, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Train the model
print("\n--- Starting Training for Model8---")
history_8 = cnn_model_8.fit(
    train_generator,
    epochs=15,
    validation_data=validation_generator,
    class_weight=class_weights
)
# Out:
# --- Starting Training for Model8---
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.7484 - loss: 0.6493 - val_accuracy: 0.4019 - val_loss: 1.0089
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7893 - loss: 0.4864 - val_accuracy: 0.4019 - val_loss: 1.3824
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7810 - loss: 0.5242 - val_accuracy: 0.4019 - val_loss: 1.7052
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7981 - loss: 0.4675 - val_accuracy: 0.4019 - val_loss: 2.2463
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7928 - loss: 0.4534 - val_accuracy: 0.4019 - val_loss: 2.4858
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8043 - loss: 0.4193 - val_accuracy: 0.4019 - val_loss: 2.5240
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.7830 - loss: 0.4476 - val_accuracy: 0.4019 - val_loss: 2.8901
# Epoch 8/15
# ...

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_8,
    validation_generator,
    dataset_name="validation data",
    class_names=class_labels
)
plot_helper.plot_history(history_8, "Model 8")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
#
# --- Evaluation on validation data ---
# Accuracy: 0.8170
# Balanced accuracy: 0.8231
# Macro F1 score: 0.8138
# Weighted F1 score: 0.8186
#
#               precision    recall  f1-score   support
#
#      healthy       0.89      0.79      0.84       317
#        tumor       0.73      0.85      0.79       213
#
#     accuracy                           0.82       530
#    macro avg       0.81      0.82      0.81       530
# weighted avg       0.83      0.82      0.82       530

# %%
cnn_helper.evaluate_and_plot_model_performance(
    cnn_model_8,
    test_generator,
    dataset_name="test data",
    class_names=class_labels
)
plot_helper.plot_history(history_8, "Model 8")
# Out:
#  4/22 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step
#
# --- Evaluation on test data ---
# Accuracy: 0.8231
# Balanced accuracy: 0.8220
# Macro F1 score: 0.8130
# Weighted F1 score: 0.8251
#
#               precision    recall  f1-score   support
#
#      healthy       0.89      0.83      0.86       437
#        tumor       0.73      0.82      0.77       247
#
#     accuracy                           0.82       684
#    macro avg       0.81      0.82      0.81       684
# weighted avg       0.83      0.82      0.83       684
